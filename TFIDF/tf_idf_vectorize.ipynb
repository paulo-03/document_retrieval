# %% [markdown]
# # TF-IDF
#
# Notebooks to show our TF-IDF method and its performances.

# %% [markdown]
# ## Import

# %%
from TFIDF.tf_idf import TFIDFVectorizer

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## TF-IDF computation

# %%
corpus = TFIDFVectorizer("../clean_data/lower_case_stop_words_lemmatization/clean_corpus_en.json")
# Out:
# Loading corpus...
# Corpus loaded successfully! Found 207363 documents in 'en'.

# %%
corpus.data
# Out:
#                 docid                                               text lang
# 0         doc-en-9633  mars hill church christian megachurch , found ...   en
# 1        doc-en-11447  joel chandler harris ( december 9 , 1848 – jul...   en
# 2         doc-en-9696  surabaya dock 14,000 ton float dry dock serve ...   en
# 3         doc-en-4033  list cicada find australia include outlying is...   en
# 4        doc-en-10997  john aaron rawlins ( february 13 , 1831 septem...   en
# ...               ...                                                ...  ...
# 207358  doc-en-719973  bird canada fifth series banknotes canadian do...   en
# 207359  doc-en-708162  nassau interim finance authority new york stat...   en
# 207360    doc-en-3808  dr . vyasanakere prabhanjanacharya ( ) ; ( bea...   en
# 207361  doc-en-653407  lav iii , originally name kodiak canadian army...   en
# 207362  doc-en-788430  western esotericism , also know esotericism , ...   en
#
# [207363 rows x 3 columns]

# %% [markdown]
# ## Dictionnary
#
# Let's have a look at the vocabulary of the documents. First we can see how many words are in the vocabulary.
#
# Also, we can have a look at the distribution of the words to see which words are the most common. Recall that every punctuation and stopwords have been remove from the data_cleaning part.

# %%
corpus.create_vocabulary(plot=True)
# Out:
# Dictionary created with 3819873 unique words/tokens !

# %% [markdown]
# ## Compute the TF-IDF matrix
#
# From the given corpus, compute the TF-IDF matrix of size (vocabulary_size X document_number).

# %%
corpus.vectorize()
# Out:
# Computing the TF matrix: 100%|██████████| 207363/207363 [03:47<00:00, 910.63it/s]
# Computing IDF...
# Done.
#
# Computing TF-IDF matrix...
# Done.
#
# The TF-IDF matrix has a shape of (207363, 3819873).

# %% [markdown]
# ## Saving the results
#
# Let's store in the disk our results. They will be used to retrieve the documents from a query later, in the tf_idf_retriever part.

# %%
corpus.save_results(path='tf_idf_matrix/lower_case_stop_words_lemmatization')
# Out:
# TF-IDF results saved successfully using pickle!
